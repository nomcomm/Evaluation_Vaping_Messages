# %% [markdown]
# # Sentence Embeddings using Siamese BERT-Networks
# ---
# This Google Colab Notebook illustrates using the Sentence Transformer python library to quickly create BERT embeddings for sentences and perform fast semantic searches.
#
# The Sentence Transformer library is available on [pypi](https://pypi.org/project/sentence-transformers/) and [github](https://github.com/UKPLab/sentence-transformers). The library implements code from the ACL 2019 paper entitled "[Sentence-BERT: Sentence Embeddings using Siamese BERT-Networks](https://www.aclweb.org/anthology/D19-1410.pdf)" by Nils Reimers and Iryna Gurevych.

# %% [markdown]
# ## Install Sentence Transformer Library

# %%
#!conda install -c conda-forge sentence-transformers -y

# %% [markdown]
# ## Load the BERT Model

# %%
from sentence_transformers import SentenceTransformer
from sentence_transformers.util import pytorch_cos_sim
import numpy as np
#np.corrcoef(sentence_embeddings).shape

import matplotlib.pyplot as plt
# %matplotlib inline
# Load the BERT model. Various models trained on Natural Language Inference (NLI) https://github.com/UKPLab/sentence-transformers/blob/master/docs/pretrained-models/nli-models.md and 
# Semantic Textual Similarity are available https://github.com/UKPLab/sentence-transformers/blob/master/docs/pretrained-models/sts-models.md

model = SentenceTransformer('stsb-mpnet-base-v2')

# %% [markdown]
# ## Setup a Corpus

# %%
### image

sentences2 = ['I like my phone',
'Your cellphone looks great',
'Will it snow tomorrow?',
'Hurricanes have hit the US',
'How old are you?',
'what is your age?',
"Folic acid (Vitamin B9) is found in green leafy vegetables and whole grains, such as oatmeal, wheat, barley, and rye. It is also found in nuts, seeds, and legumes.",
'Reduces the risk of neural tube defects, and the most common form of neural tube defect is spina bifida.',
"We want to remind you that folic acid is a B vitamin, and is important for the development of healthy cells in the body.",
"Most but not all neural tube defects can be explained by low levels of #folate",
"In many countries, staple foods like wheat & maize flour are fortified w/ #folate to reduce the risk of neural tube defects",
'The risk of neural tube defects is reduced if women consume 400 micrograms of #folate every day before and during early pregnancy',]

sentence_embeddings2 = model.encode(sentences2)

# %%
matcos2 = np.zeros((len(sentences2),len(sentences2)))
for i in range(len(sentences2)):
  for j in range (len(sentences2)):
    matcos2[i,j] = pytorch_cos_sim(sentence_embeddings2[i,:], sentence_embeddings2[j,:])

#np.fill_diagonal(matcos2, np.NaN)


fig, ax = plt.subplots()
im = ax.imshow(matcos2, cmap = 'YlOrRd', vmin = 0, vmax = 1);

ax.set_yticks(np.arange(len(sentences2)))
ax.set_yticklabels(sentences2)

fig.colorbar(im, ax=ax)
plt.show()

# %%
# A corpus is a list with documents split by sentences.

#top 30 are AI-gen (with prompts), bottom 30 are human

sentences = ["Consuming folic acid is important because it is essential to the formation of red blood cells, and in the process of cell division. A deficiency of folic acid in the diet may lead to neural tube defects in the fetus.",
                "Consuming folic acid is important because it can help prevent birth defects that affect the nervous system, such as spina bifida. It can also prevent birth defects that affect the heart and blood vessels. It also helps prevent birth defects that affect the eyes, ears, and nose.",
                "Consuming folic acid is important because it helps to prevent neural tube defects (NTDs) in pregnant women. It is also essential for the production of red blood cells and DNA synthesis, and it helps to maintain healthy immune function. Folic acid is a B vitamin.",
                "Consuming folic acid is important because it is essential for the synthesis of DNA and RNA, as well as for the formation of red blood cells. It is also important for the prevention of certain types of cancer and heart disease.",
                "Consuming folic acid is important because folic acid is a B vitamin that is necessary for the synthesis of DNA and RNA. Folate is a nutrient that is important for a healthy baby's brain and nervous system development",
                "Folic acid during pregnancy reduces the risk of neural tube defects, and the most common form of neural tube defect is spina bifida.",
                "Folic acid during pregnancy is also associated with decreased risk of birth defects and neurological impairments in infants. Inadequate folate intake is associated with increased risk of neural tube defects (NTDs) such as spina bifida and anencephaly.",
                "Folic acid during pregnancy reduces the risk of neural tube defects (NTDs) in the foetus. The risk of NTDs is increased in women who have a history of NTDs in their family. The foetus develops from the first two weeks of pregnancy.",
                "Folic acid during pregnancy is essential to maintain normal maternal and fetal health. Deficiencies of folic acid have been linked to neural tube defects (NTDs) in humans. Folic acid is a water-soluble B-vitamin that is involved in several biochemical reactions and acts as",
                "Folic acid during pregnancy is associated with a decreased risk of neural tube defects and spina bifida. This is achieved by preventing the methylation of the DNA, and thus the formation of a gene that is responsible for the development of the neural tube and the spinal cord.", 
                "Every woman needs #folicacid every day, especially if you're trying to conceive. Here are some great resources for more information. #FolicAcid #pregnancy #fertility #fertilityinsight #fertilitytips #fertilization #fertilitynews #fertilityins",
                "Every woman needs #folicacid every day, no matter her age or pregnancy history. Folic acid helps prevent birth defects, like spina bifida, and helps your baby grow healthy. Learn more about #folicacid here. #mamaandbaby #healthyfamily #health",
                "Every woman needs #folicacid every day, especially during her reproductive years. This is important for preventing birth defects, including #anencephaly. This is an incredibly rare birth defect where the baby has no brain or skull.",
                "Every woman needs #folicacid every day, even if she hasn't had a baby. It can help prevent birth defects like spina bifida, which can cause severe physical and mental disabilities. #folicacid #pregnancy #birth #spina_bifida",
                "Every woman needs #folicacid every day, even if you don't have a medical condition that requires it. If you don't have a medical condition, take 400 mcg per day. #fertility #infertility #fertilityblog #infertilityjourney #fertilitytips", 
                "Did you know, #Folicacid helps to keep your #heart healthy? Know your #vitamind levels. This is a #vitamin that is critical for a healthy #body.#VitaminD is found in #sunlight, and #dietary sources.#Vitamin",
                "Did you know, #Folicacid is the most common vitamin in the world, but only about 20% of us have enough of it? It's found in many foods, including green leafy vegetables, but most people don't get enough of it. ",
                "Did you know, #Folicacid is an important nutrient for women, but can be hard to get? Learn more about folic acid and its benefits in our #HealthTip. #Dietitian #Healthy #Women #Wellness #HealthyLife #HealthyLiving #Health",
                "Did you know, #Folicacid is essential for optimal health and #fertility? #pregnancy #pregnant #pregnantmom #pregnancytips #pregnancyweek #pregnancyweek2 #pregnancyweek3 #pregnancyweek4",
                "Did you know, #Folicacid is a nutrient that helps prevent birth defects, like #spinaBifida and #anencephaly? #VitaminD helps your body absorb #folate, a nutrient that helps prevent birth defects",
                "It's National Folic Acid Awareness week! In honor of this week I am going to share with you the most important thing I know about folic acid. Folate is an essential nutrient that is vital to the health of the body.",
                "It's National Folic Acid Awareness week! Folate, or folic acid, is a B vitamin that is important for healthy growth and development. However, most of us don't get enough of it in our diet.",
                "It's National Folic Acid Awareness week so let's talk about folic acid. Folic acid is a B vitamin that is important for the body. Folate is found naturally in many foods and is made synthetically in a number of foods that are fortified with folic acid.", 
                "It's National Folic Acid Awareness week and I'm here to remind you that folic acid is important. Folate, the B-vitamin folic acid is one of the most important nutrients we need in our diets.", 
                "It's National Folic Acid Awareness week, and we want to remind you that folic acid is a B vitamin, and is important for the development of healthy cells in the body.",
                "Consume folic acid:  This is the form of folate that is most commonly found in foods.  It is important for healthy cells and tissues and for maintaining normal blood levels of homocysteine.  In addition, folic acid helps to prevent birth defects and neural tube defects.", 
                "Consume folic acid: Folic acid (Vitamin B9) is found in green leafy vegetables and whole grains, such as oatmeal, wheat, barley, and rye. It is also found in nuts, seeds, and legumes.",
                "Consume folic acid: Folic acid is a B vitamin that helps prevent birth defects. If you are pregnant, you need to consume at least 400 micrograms of folic acid per day. This can be done through the foods you eat or supplements.",
                "Consume folic acid: The most effective method to deal with the problem of hair loss is to consume more folic acid. Folic acid aids to improve the flow of blood to the head and also boosts the growth of hair.",
                "Consume folic acid: Folate is a B vitamin that is important for the development of your baby's brain. It is found in green leafy vegetables, legumes, meat, and dairy products. Your diet should include at least 400 micrograms (mcg) per day.",
            "This is fantastic news, very pleased that government has finally accepted the strong evidence for this policy. #Folicacid to be added to UK flour in effort to reduce birth defects.",
                "Dark green vegetables like broccoli and spinach and dried legumes such as chickpeas, beans and lentils are good sources of #folate",
                "The risk of neural tube defects is reduced if women consume 400 micrograms of #folate every day before and during early pregnancy",
                "Every woman needs #folicacid every day, whether shes planning to get pregnant or not. Check out this video for a smoothie recipe to get the recommended 400 micrograms of folic acid.",
                "Most but not all neural tube defects can be explained by low levels of #folate",
                "This study is loaded with gems on how a #lowcarb diet improves #liver (and general) health: improved #lipids, #insulinresistance, #NAFLD, and more. Also, lowcarb also improved #gut bacteria, including #folate-producing bacteria.",
                "#FolicAcid during pregnancy may prevent #ChildhoodObesity. Dr. Alva Roche Green explains in this #MayoClinicMinute.",
                "Its National Folic Acid Awareness Week. Ladies, make sure to get 400 micrograms of #folicacid today & every day. #Prevent2Protect",
                "Did you know, #Beets are good for the heart and great for the brain? Theyre also excellent for lowering blood pressure! These powerful root vegetables are filled with #VitaminC, #Magnesium, and #Folate.",
                "Eat these #folate rich foods for overall better #health - #Fitness #Tips #Vitamins",
                "#DYK you can reduce baby's risk of spina bifida or anencephaly with #folicacid BEFORE #pregnancy? #Prevent2Protect",
                "Did you know serious birth defects can be prevented if women get #FolicAcid daily starting BEFORE pregnancy? Get 400mcg of folic acid daily for your babys protection. For more information visit:",
                "Neural tube defects are serious birth defects of a babys brain & spine. Taking a multivitamin with #folicacid is one way to your chance of having a baby with one of these conditions. Learn other steps you can take: #Best4YouBest4Baby",
                "Consume #folicacid: CDC recommends that women who can become pregnant should get 400 mcg every day. #Prevent2Protect",
                "You can find this essential nutrient naturally in legumes like chickpeas #folate",
                "High-dose #folicacid supplements taken after the first trimester of #pregnancy did not prevent #preeclampsia in high-risk women",
                "In many countries, staple foods like wheat & maize flour are fortified w/ #folate to reduce the risk of neural tube defects",
                "Doesnt matter when you take folate when on #Methotrexate. Small study but #folate with #mtx was same as taking #folic acid 1 day later. Interesting. I usually say take folate not on day of Mtx but likely doesnt matter.",
                "Did you take your #folicacid supplement today? Women who can become pregnant need 400 micrograms daily in addition to a healthy diet. Learn why:",
                "Taking 400 mcg of #folicacid daily can help women prevent some serious birth defects. Learn more: ",
                "What Are Vitamins for Healthy Immune System? Discover the Top 5 that make a huge difference how your #ImmuneSystem fights infection. #women #womenshealth #healthyliving #supplements #vitamins #vitaminc #folicacid #vitaminb #zinc",
                "Looking for a healthy, easy way to get your folic acid? Take a multivitamin with #folicacid or try this smoothie #recipe. #WorldHealthDay #ManyBirthDefects1Voice",
                "Study Sufficient intake of #folicacid during #pregnancy reduces the risk of #congenitalheartdefects in fetus.",
                "Remember to get 400 micrograms of #folicacid every day. Make folic acid part of your morning routine! Learn why its important, especially for women:",
                "Wow, I am amazed at all the positive changes in my skin, and who knows what else, since I've started taking #Niacin 500mg, at night, with 500mg #VitaminC In the morning, #Zinc 50mg, VitC, #VitaminD #FolicAcid I want to know if this works for #acne",
                "Women who smoked cigarettes during #pregnancy and took higher-dose #folicacid supplements delivered infants with better fetal growth than #smokers who took standard-dose folic acid, according to a study published in",
                "Increasing global #FolicAcid fortification can help prevent 150,000-210,000 neural tube defects worldwide each year.",
                "When a woman gets enough #folicacid BEFORE & DURING pregnancy, it can prevent major birth defects.",
                "#Folate helps the body produce healthy red blood cells that transport oxygen to your tissues",
                "Hot off the press! Our new paper shows that continued #folicacid supplementation at a dose of 400 microgram daily, beyond the early period of pregnancy recommended for NTD prevention, may be beneficial for cognitive function and IQ of the child #NICHEbvits" 
            ]

# Each sentence is encoded as a 1-D vector with 78 columns
sentence_embeddings = model.encode(sentences)

print('Sample BERT embedding vector - length', len(sentence_embeddings[0]))

print('Sample BERT embedding vector - note includes negative values', sentence_embeddings[0])
# Out:
# Sample BERT embedding vector - length 768
# Sample BERT embedding vector - note includes negative values [ 4.60150130e-02 -7.70916417e-02  4.69258018e-02  8.55528638e-02
#   1.20291717e-01  6.60203174e-02 -7.13457689e-02  5.59259206e-03
#  -1.63432565e-02 -4.54246290e-02  4.64420468e-02  2.77020335e-02
#  -1.14618242e-01  2.46615633e-02  3.68754007e-02  2.77969148e-02
#   1.97305545e-01 -2.15486407e-01 -3.04355413e-01  3.36631648e-02
#   7.19045475e-02  1.77289560e-01  6.31766021e-02  3.26265901e-04
#  -1.54819503e-01  3.35046202e-02  1.88996360e-01  9.69983935e-02
#   3.39696519e-02  7.32915327e-02 -6.25249743e-02  7.38320500e-02
#  -6.58526719e-02  1.35113105e-01 -4.79364991e-02  9.39690787e-03
#  -6.33969530e-02  4.79842685e-02 -3.05030751e-03  1.29425414e-02
#   1.67103961e-01  4.99305241e-02 -1.31846024e-02 -3.31084505e-02
#   2.62307618e-02  1.16216362e-01  2.38297120e-01  1.36816213e-02
#   1.63178872e-02  5.33829071e-02  7.63882324e-02 -1.04196839e-01
# ...

# %%
sentence_embeddings.shape
# Out:
# (60, 768)

# %%
plt.imshow(np.corrcoef(sentence_embeddings)[:, :], cmap = 'seismic', vmin = 0, vmax = 1);
plt.colorbar()

# %%
hypo = np.zeros((60,60))
hypo[:30,:30] = 1
hypo[30:,30:] = 1
plt.imshow(hypo, cmap = 'YlOrRd', vmin = 0, vmax = 1);
plt.colorbar()

# %%
mat = np.corrcoef(sentence_embeddings)

m1 = mat[:30, :30]
m1.shape
# Out:
# (30, 30)

# %%
matcos = np.zeros((60,60))
for i in range(60):
  for j in range (60):
    matcos[i,j] = pytorch_cos_sim(sentence_embeddings[i,:], sentence_embeddings[j,:])

plt.imshow(matcos, cmap = 'YlOrRd', vmin = 0, vmax = 1);
plt.colorbar()
plt.show()

plt.imshow(np.corrcoef(sentence_embeddings)[:, :], cmap = 'YlOrRd', vmin = 0, vmax = 1);
plt.colorbar()
import seaborn as sns

sns.despine(left=True, bottom=True)
plt.xticks([])
plt.yticks([])

import nilearn.connectome

cos = nilearn.connectome.sym_matrix_to_vec(matcos, discard_diagonal=True)
cor = nilearn.connectome.sym_matrix_to_vec(mat, discard_diagonal=True)
np.corrcoef(cos, cor)
# Out:
# array([[1.        , 0.99999048],
#        [0.99999048, 1.        ]])

# %%
import nilearn.connectome
aigens = nilearn.connectome.sym_matrix_to_vec(matcos[:30, :30], discard_diagonal=True)
humans = nilearn.connectome.sym_matrix_to_vec(matcos[30:, 30:], discard_diagonal=True)
aitohum = nilearn.connectome.sym_matrix_to_vec(matcos[30:, :30], discard_diagonal=True)

print(np.mean(aigens))
print(np.mean(humans))
print(np.mean(aitohum))
# Out:
# 0.5797669958451699
# 0.43402180870374046
# 0.4732889652937308

# %%
aimeans  =  np.nanmean(matcos[:30, :30], axis = 0)
hummeans =  np.nanmean(matcos[30:, 30:], axis = 0)
aitohummeans  =  np.nanmean(matcos[30:, :30], axis = 0)

print(np.mean(aimeans))
print(np.mean(hummeans))
print(np.mean(aitohummeans))

from scipy import stats
print(stats.ttest_ind(aimeans, hummeans))
print(stats.ttest_ind(aimeans, aitohummeans))
print(stats.ttest_ind(aitohummeans, hummeans))
# Out:
# 0.5937747627165582
# 0.45288774775134194
# 0.4728032474882073
# Ttest_indResult(statistic=8.46822514428344, pvalue=1.0103565584367528e-11)
# Ttest_indResult(statistic=8.210764331021412, pvalue=2.717901151881733e-11)
# Ttest_indResult(statistic=1.366432957659717, pvalue=0.17707734063940433)

# %%
np.nanmean(matcos)
# Out:
# 0.4980672513610787

# %%
### image

sentences2 = ['I like my phone',
'Your cellphone looks great',
'Will it snow tomorrow?',
'Hurricanes have hit the US',
'How old are you?',
'what is your age?',]

sentence_embeddings2 = model.encode(sentences2)

matcos2 = np.zeros((len(sentences2),len(sentences2)))
for i in range(len(sentences2)):
  for j in range (len(sentences2)):
    matcos2[i,j] = pytorch_cos_sim(sentence_embeddings2[i,:], sentence_embeddings2[j,:])

#np.fill_diagonal(matcos2, np.NaN)


fig, ax = plt.subplots()
im = ax.imshow(matcos2, cmap = 'YlOrRd', vmin = 0, vmax = 1);

ax.set_yticks(np.arange(len(sentences2)))
ax.set_yticklabels(sentences2)

fig.colorbar(im, ax=ax)
plt.show()

# %% [markdown]
# ## Perform Semantic Search

# %%
import scipy
#@title Sematic Search Form

# code adapted from https://github.com/UKPLab/sentence-transformers/blob/master/examples/application_semantic_search.py

query = 'Nobody has sane thoughts' #@param {type: 'string'}

queries = [query]
query_embeddings = model.encode(queries)

# Find the closest 5 sentences of the corpus for each query sentence based on cosine similarity
number_top_matches = 5 #@param {type: "number"}

print("Semantic Search Results")

for query, query_embedding in zip(queries, query_embeddings):
    distances = scipy.spatial.distance.cdist([query_embedding], sentence_embeddings, "cosine")[0]

    results = zip(range(len(distances)), distances)
    results = sorted(results, key=lambda x: x[1])

    print("\n\n======================\n\n")
    print("Query:", query)
    print("\nTop 5 most similar sentences in corpus:")

    for idx, distance in results[0:number_top_matches]:
        print(sentences[idx].strip(), "(Cosine Score: %.4f)" % (1-distance))
# Out:
# Semantic Search Results
#
#
# ...
#
#
# Query: Nobody has sane thoughts
#
# Top 5 most similar sentences in corpus:
# especially during her reproductive years. This is important for preventing birth defects, including #anencephaly. This is an incredibly rare birth defect where the baby has no brain or skull. (Cosine Score: 0.2192)
# Doesnt matter when you take folate when on #Methotrexate. Small study but #folate with #mtx was same as taking #folic acid 1 day later. Interesting. I usually say take folate not on day of Mtx but likely doesnt matter. #EULAR2022 #POS0695 (Cosine Score: 0.1354)
# is also associated with decreased risk of birth defects and neurological impairments in infants. Inadequate folate intake is associated with increased risk of neural tube defects (NTDs) such as spina bifida and anencephaly. (Cosine Score: 0.1177)
# Most but not all neural tube defects can be explained by low levels of #folate (Cosine Score: 0.1165)
# ...
